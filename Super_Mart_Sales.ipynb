# %%
#Importing Libraries

# %%
import pandas as pd
import numpy as np
import seaborn as sns 
import matplotlib.pyplot as plt
import warnings 
warnings.filterwarnings('ignore')
# Out:
# C:\Users\as\AppData\Roaming\Python\Python311\site-packages\pandas\core\arrays\masked.py:60: UserWarning: Pandas requires version '1.3.6' or newer of 'bottleneck' (version '1.3.5' currently installed).
#   from pandas.core import (

# %%
## Loading data from csv file to dataframe

# %%
df=pd.read_csv("supermarket_sales - Sheet1.csv")

# %%
df.head()
# Out:
#     Invoice ID Branch       City Customer type  Gender  \
# 0  750-67-8428      A     Yangon        Member  Female
# 1  226-31-3081      C  Naypyitaw        Normal  Female
# 2  631-41-3108      A     Yangon        Normal    Male
# 3  123-19-1176      A     Yangon        Member    Male
# 4  373-73-7910      A     Yangon        Normal    Male
#
#              Product line  Unit price  Quantity   Tax 5%     Total       Date  \
# 0       Health and beauty       74.69         7  26.1415  548.9715   1/5/2019
# 1  Electronic accessories       15.28         5   3.8200   80.2200   3/8/2019
# 2      Home and lifestyle       46.33         7  16.2155  340.5255   3/3/2019
# 3       Health and beauty       58.22         8  23.2880  489.0480  1/27/2019
# 4       Sports and travel       86.31         7  30.2085  634.3785   2/8/2019
#
#     Time      Payment    cogs  gross margin percentage  gross income  Rating
# 0  13:08      Ewallet  522.83                 4.761905       26.1415     9.1
# ...

# %%
df.tail()
# Out:
#       Invoice ID Branch       City Customer type  Gender         Product line  \
# 995  233-67-5758      C  Naypyitaw        Normal    Male    Health and beauty
# 996  303-96-2227      B   Mandalay        Normal  Female   Home and lifestyle
# 997  727-02-1313      A     Yangon        Member    Male   Food and beverages
# 998  347-56-2442      A     Yangon        Normal    Male   Home and lifestyle
# 999  849-09-3807      A     Yangon        Member  Female  Fashion accessories
#
#      Unit price  Quantity   Tax 5%      Total       Date   Time  Payment  \
# 995       40.35         1   2.0175    42.3675  1/29/2019  13:46  Ewallet
# 996       97.38        10  48.6900  1022.4900   3/2/2019  17:16  Ewallet
# 997       31.84         1   1.5920    33.4320   2/9/2019  13:22     Cash
# 998       65.82         1   3.2910    69.1110  2/22/2019  15:33     Cash
# 999       88.34         7  30.9190   649.2990  2/18/2019  13:28     Cash
#
# ...

# %%
df.describe
# Out:
# <bound method NDFrame.describe of       Invoice ID Branch       City Customer type  Gender  \
# 0    750-67-8428      A     Yangon        Member  Female
# 1    226-31-3081      C  Naypyitaw        Normal  Female
# 2    631-41-3108      A     Yangon        Normal    Male
# 3    123-19-1176      A     Yangon        Member    Male
# 4    373-73-7910      A     Yangon        Normal    Male
# ..           ...    ...        ...           ...     ...
# 995  233-67-5758      C  Naypyitaw        Normal    Male
# 996  303-96-2227      B   Mandalay        Normal  Female
# 997  727-02-1313      A     Yangon        Member    Male
# 998  347-56-2442      A     Yangon        Normal    Male
# 999  849-09-3807      A     Yangon        Member  Female
#
#                Product line  Unit price  Quantity   Tax 5%      Total  \
# 0         Health and beauty       74.69         7  26.1415   548.9715
# 1    Electronic accessories       15.28         5   3.8200    80.2200
# ...

# %%
df.shape
# Out:
# (1000, 17)

# %%
df.info
# Out:
# <bound method DataFrame.info of       Invoice ID Branch       City Customer type  Gender  \
# 0    750-67-8428      A     Yangon        Member  Female
# 1    226-31-3081      C  Naypyitaw        Normal  Female
# 2    631-41-3108      A     Yangon        Normal    Male
# 3    123-19-1176      A     Yangon        Member    Male
# 4    373-73-7910      A     Yangon        Normal    Male
# ..           ...    ...        ...           ...     ...
# 995  233-67-5758      C  Naypyitaw        Normal    Male
# 996  303-96-2227      B   Mandalay        Normal  Female
# 997  727-02-1313      A     Yangon        Member    Male
# 998  347-56-2442      A     Yangon        Normal    Male
# 999  849-09-3807      A     Yangon        Member  Female
#
#                Product line  Unit price  Quantity   Tax 5%      Total  \
# 0         Health and beauty       74.69         7  26.1415   548.9715
# 1    Electronic accessories       15.28         5   3.8200    80.2200
# ...

# %%
df.dropna()
# Out:
#       Invoice ID Branch       City Customer type  Gender  \
# 0    750-67-8428      A     Yangon        Member  Female
# 1    226-31-3081      C  Naypyitaw        Normal  Female
# 2    631-41-3108      A     Yangon        Normal    Male
# 3    123-19-1176      A     Yangon        Member    Male
# 4    373-73-7910      A     Yangon        Normal    Male
# ..           ...    ...        ...           ...     ...
# 995  233-67-5758      C  Naypyitaw        Normal    Male
# 996  303-96-2227      B   Mandalay        Normal  Female
# 997  727-02-1313      A     Yangon        Member    Male
# 998  347-56-2442      A     Yangon        Normal    Male
# 999  849-09-3807      A     Yangon        Member  Female
#
#                Product line  Unit price  Quantity   Tax 5%      Total  \
# 0         Health and beauty       74.69         7  26.1415   548.9715
# 1    Electronic accessories       15.28         5   3.8200    80.2200
# ...

# %%
df.dropna(inplace=True)

# %%
df.columns
# Out:
# Index(['Invoice ID', 'Branch', 'City', 'Customer type', 'Gender',
#        'Product line', 'Unit price', 'Quantity', 'Tax 5%', 'Total', 'Date',
#        'Time', 'Payment', 'cogs', 'gross margin percentage', 'gross income',
#        'Rating'],
#       dtype='object')

# %%
plt.figure(figsize=(10, 6))
sns.countplot(x='City', data=df, palette='pastel')  # You can use any predefined palette here
plt.title('Sales Distribution by City')
plt.xlabel('City')
plt.ylabel('Number of Sales')
plt.show()

# %% [markdown]
# Above bar chart displays sales distribution across three Myanmar cities: Yangon, Naypyitaw, and Mandalay. Yangon leads with about 340 sales, followed closely by Mandalay (335) and Naypyitaw (330).
# The chart shows relatively uniform sales performance across these major urban centers, with only slight variations between them.

# %%
plt.figure(figsize=(12, 6))
sns.barplot(x='Product line', y='Rating', data=df, palette='viridis')  # Using the 'viridis' palette
plt.title('Average Rating by Product Line')
plt.xlabel('Product Line')
plt.ylabel('Average Rating')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# #Above bar chart displays the average ratings for six different product lines.
# All product categories have high ratings between 6.9 and 7.1 out of 10,
# Fashion accessories and Food and beverages show slightly higher ratings,
# while Health and beauty has the lowest, but differences are minimal.
# Error bars indicate some variation within each category.
# Overall, the chart suggests consistently positive customer satisfaction across all product lines.

# %%
plt.figure(figsize=(10, 6))
sns.countplot(x='Payment', data=df, palette='Set2')  
plt.title('Total Sales by Payment Method')
plt.xlabel('Payment Method')
plt.ylabel('Number of Sales')
plt.show()

# %% [markdown]
# This bar chart illustrates the total sales by payment method. E-wallet leads with approximately 345 sales, followed closely by cash at around 340 sales. Credit card shows the lowest number of sales at about 310. The chart uses different colors for each payment method and clearly displays the number of sales on the y-axis, providing a quick visual comparison of payment preferences among customers.

# %%
payment_counts = df['Payment'].value_counts()


labels = payment_counts.index
sizes = payment_counts.values


colors = ['#FF9999', '#66B3FF', '#99FF99']


plt.figure(figsize=(6, 6))
plt.pie(sizes, labels=labels, colors=colors, autopct='%1.1f%%', startangle=140, pctdistance=0.85)


centre_circle = plt.Circle((0,0), 0.70, fc='white')
fig = plt.gcf()
fig.gca().add_artist(centre_circle)

# Equal aspect ratio ensures that pie is drawn as a circle
plt.title('Total Sales by Payment Method')
plt.axis('equal')  

# Display the chart
plt.show()

# %% [markdown]
# This donut chart displays the distribution of total sales by payment method. E-wallet is the most popular at 34.5%, followed closely by cash at 34.4%. Credit card transactions account for 31.1% of sales. The chart uses distinct colors for each payment method and shows percentages, offering a clear visual representation of the relative popularity of each payment option.

# %%
plt.figure(figsize=(12, 8))
sns.countplot(x='Product line', hue='Gender', data=df, palette='pastel')

# Set plot title and labels
plt.title('Sales Distribution by Gender and Product Line')
plt.xlabel('Product Line')
plt.ylabel('Number of Sales')
plt.xticks(rotation=45)

# Display the graph
plt.legend(title='Gender')
plt.show()

# %%
sales_over_time = df.groupby('Date')['Total'].sum().reset_index()

# %%
plt.figure(figsize=(12, 6))
plt.plot(sales_over_time['Date'], sales_over_time['Total'], marker='o', linestyle='-', color='b')
plt.title('Sales Over Time')
plt.xlabel('Date')
plt.ylabel('Total Sales')
plt.grid(True)
plt.show()

# %%
sales_by_gender = df.groupby('Gender')['Total'].sum().reset_index()

# %%
plt.figure(figsize=(8, 5))
plt.bar(sales_by_gender['Gender'], sales_by_gender['Total'], color=['#FF9999', '#66B3FF'])
plt.title('Total Sales by Gender')
plt.xlabel('Gender')
plt.ylabel('Total Sales')
plt.show()
